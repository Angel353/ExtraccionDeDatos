# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel353/ExtraccionDeDatos/blob/main/Ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar las librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carga desde un archivo .xlsx sin indice
df_pp = pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')
df_pp
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0     F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1     F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4     F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...      ...        ...                        ...
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                     NOMBRE_CLIENTE  CANT       CVE_ART  \
# 0               PÚBLICO EN GENERAL     1      TUE00244
# 1     JUAN ANTONIO RESENDIZ UGALDE     1      TUA00028
# 2        ANA BARBARA CRUZ PALACIOS     7        TP0007
# 3             OMAR RODRIGUEZ GOMEZ     1        TP0001
# 4               PÚBLICO EN GENERAL     2       BP00242
# ...

# %%
# Filtro 1 (Nombre de vendedor)
filtro1 = df_pp[df_pp["NOMBRE_VENDEDOR"] == "AARON NUÑO CORDOVA"]
filtro1
# Out:
#      CVE_DOC  FECHA_DOC     NOMBRE_VENDEDOR  \
# 24    F37069 2022-01-07  AARON NUÑO CORDOVA
# 43    F37107 2022-01-12  AARON NUÑO CORDOVA
# 88    F37192 2022-01-25  AARON NUÑO CORDOVA
# 116   F37249 2022-01-31  AARON NUÑO CORDOVA
# 275   F37541 2022-03-03  AARON NUÑO CORDOVA
# ...      ...        ...                 ...
# 1417  F39833 2022-12-23  AARON NUÑO CORDOVA
# 1418  F39833 2022-12-23  AARON NUÑO CORDOVA
# 1419  F39833 2022-12-23  AARON NUÑO CORDOVA
# 1420  F39833 2022-12-23  AARON NUÑO CORDOVA
# 1425  F39838 2022-12-23  AARON NUÑO CORDOVA
#
#                                   NOMBRE_CLIENTE  CANT   CVE_ART  \
# 24                             ADVANEX DE MEXICO     2   RP00150
# 43                         ENRIQUE VAZQUEZ PEREZ     8  TUA00404
# 88    COMERCIALIZADORA DE REPUESTOS INDUSTRIALES    20    TP0003
# 116        INGENIERIA DE PLASTICOS E IMPRESIONES     2   BB00077
# 275                          KERN LIEBERS MEXICO     2   TK00028
# ...

# %%
# Convertir filtro 1 en CSV
#filtro1.to_csv("filtro1.csv")

# %%
# Filtro 2 (Filtro por fila)
filtro2_pp = df_pp.iloc[3:6, : ]  # Filas consecutivas
filtro2_pp
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR        NOMBRE_CLIENTE  CANT  \
# 3  F37042 2022-01-05   DIEGO ARMANDO LEON DURAN  OMAR RODRIGUEZ GOMEZ     1
# 4  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ    PÚBLICO EN GENERAL     2
# 5  F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ    PÚBLICO EN GENERAL     2
#
#    CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 3   TP0001     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 1 MT           140.00
# 4  BP00242  BAN P INOX 115MMX235MM 1000W 127V T/TOR           172.41
# 5  BP00243    BAN P INOX 55MMX235MM 450W 127V T/TOR           237.07
#
#    COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 3           38.96                     38.96            140.00
# 4          101.71                    101.71            344.83
# 5           49.41                     49.41            474.14
#
#    COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# ...

# %%
# Convertir filtro 2 en CSV
#filtro2_pp.to_csv("filtro2.csv")

# %%
# Filtro 3 (Filtro por columna)
filtro3_pp = df_pp.iloc[:, [0,1,3,8]] #Columnas no consecutivas
filtro3_pp
# Out:
#      CVE_DOC  FECHA_DOC                NOMBRE_CLIENTE  COSTO_UNITARIO
# 0     F37034 2022-01-05            PÚBLICO EN GENERAL           52.80
# 1     F37036 2022-01-05  JUAN ANTONIO RESENDIZ UGALDE          327.18
# 2     F37041 2022-01-05     ANA BARBARA CRUZ PALACIOS          177.68
# 3     F37042 2022-01-05          OMAR RODRIGUEZ GOMEZ           38.96
# 4     F37043 2022-01-05            PÚBLICO EN GENERAL          101.71
# ...      ...        ...                           ...             ...
# 1421  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ          102.31
# 1422  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ          104.69
# 1423  F39835 2022-12-23          SEVEN DAYS ALL SPORT            0.00
# 1424  F39837 2022-12-23           REVUELTA MONTECARLO         1884.35
# 1425  F39838 2022-12-23                CPEG SOLUTIONS            0.00
#
# [1426 rows x 4 columns]

# %%
# Convertir filtro 3 en CSV
# filtro3_pp.to_csv("filtro3.csv")

# %%
df1= pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col=3)
df1
# Out:
#                              CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# NOMBRE_CLIENTE
# PÚBLICO EN GENERAL            F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# JUAN ANTONIO RESENDIZ UGALDE  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ANA BARBARA CRUZ PALACIOS     F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# OMAR RODRIGUEZ GOMEZ          F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# PÚBLICO EN GENERAL            F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# ...                              ...        ...                        ...
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# LUIS ENRIQUE PATIÑO PEREZ     F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# SEVEN DAYS ALL SPORT          F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# REVUELTA MONTECARLO           F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ
# CPEG SOLUTIONS                F39838 2022-12-23         AARON NUÑO CORDOVA
#
#                               CANT       CVE_ART  \
# ...

# %%
#Filtro 4: Aplicamos Filtro de filas vs columnas
filtro4=df1.loc[["PÚBLICO EN GENERAL"], ["CANT"]]
filtro4
# Out:
#                     CANT
# NOMBRE_CLIENTE
# PÚBLICO EN GENERAL     1
# PÚBLICO EN GENERAL     2
# PÚBLICO EN GENERAL     2
# PÚBLICO EN GENERAL     4
# PÚBLICO EN GENERAL     2
# ...                  ...
# PÚBLICO EN GENERAL     2
# PÚBLICO EN GENERAL     1
# PÚBLICO EN GENERAL     4
# PÚBLICO EN GENERAL     1
# PÚBLICO EN GENERAL     2
#
# [94 rows x 1 columns]

# %%
#Filtro por cabecera
filtro5=df_pp.head(11)
filtro5
# Out:
#    CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 0   F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 1   F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 2   F37041 2022-01-05   DIEGO ARMANDO LEON DURAN
# 3   F37042 2022-01-05   DIEGO ARMANDO LEON DURAN
# 4   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 5   F37043 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 6   F37044 2022-01-05   DIEGO ARMANDO LEON DURAN
# 7   F37046 2022-01-05  LETICIA RAMIREZ HERNANDEZ
# 8   F37048 2022-01-05   DIEGO ARMANDO LEON DURAN
# 9   F37049 2022-01-05   DIEGO ARMANDO LEON DURAN
# 10  F37050 2022-01-05   DIEGO ARMANDO LEON DURAN
#
#                          NOMBRE_CLIENTE  CANT   CVE_ART  \
# 0                    PÚBLICO EN GENERAL     1  TUE00244
# 1          JUAN ANTONIO RESENDIZ UGALDE     1  TUA00028
# 2             ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                  OMAR RODRIGUEZ GOMEZ     1    TP0001
# 4                    PÚBLICO EN GENERAL     2   BP00242
# ...

# %%
#Filtro por finales
filtro6=df.tail(11)
filtro6
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR             NOMBRE_CLIENTE  \
# 1415  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ                     TORJJS
# 1416  F39830 2022-12-23  LETICIA RAMIREZ HERNANDEZ                     TORJJS
# 1417  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1418  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1419  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1420  F39833 2022-12-23         AARON NUÑO CORDOVA            TRILOGIQ-MEXICO
# 1421  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1422  F39834 2022-12-23  LETICIA RAMIREZ HERNANDEZ  LUIS ENRIQUE PATIÑO PEREZ
# 1423  F39835 2022-12-23  LETICIA RAMIREZ HERNANDEZ       SEVEN DAYS ALL SPORT
# 1424  F39837 2022-12-23  LETICIA RAMIREZ HERNANDEZ        REVUELTA MONTECARLO
# 1425  F39838 2022-12-23         AARON NUÑO CORDOVA             CPEG SOLUTIONS
#
# ...

# %%
#Filtro por comparacion
filtro7=df_pp[df_pp["PRECIO_UNITARIO"] > 30000]
filtro7
# Out:
#     CVE_DOC  FECHA_DOC NOMBRE_VENDEDOR      NOMBRE_CLIENTE  CANT  CVE_ART  \
# 672  F38352 2022-06-10  ALFREDO CANELA  FLEX-N-GATE MEXICO     1  RP00203
#
#                                 DESCR  PRECIO_UNITARIO  COSTO_UNITARIO  \
# 672  REPARACION HORNO 15KW 440V TOTAL         32582.18             0.0
#
#      COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  COSTO_TOTAL_CALCULADO  \
# 672                 199335.56          32582.18              199335.56
#
#      MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# 672                 -166753.38              -166753.38

# %%
#Filtro Y (AND)
filtro8=df_pp[(df_pp["PRECIO_UNITARIO"] > 15000) & (df["COSTO_UNITARIO"] < 25)]
filtro8
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 373   F37734 2022-03-28   DIEGO ARMANDO LEON DURAN
# 419   F37817 2022-03-31             ALFREDO CANELA
# 672   F38352 2022-06-10             ALFREDO CANELA
# 866   F38705 2022-07-29             ALFREDO CANELA
# 1046  F39088 2022-09-20  LETICIA RAMIREZ HERNANDEZ
# 1101  F39191 2022-09-30  LETICIA RAMIREZ HERNANDEZ
# 1104  F39201 2022-09-30             ALFREDO CANELA
# 1253  F39503 2022-11-04             ALFREDO CANELA
# 1288  F39576 2022-11-15             ALFREDO CANELA
#
#                                          NOMBRE_CLIENTE  CANT   CVE_ART  \
# 373                                   DIECASTING CELAYA     2   BO00005
# 419          FABRICACION Y MONTAJE DE EQUIPO INDUSTRIAL     1  GAB00014
# 672                                  FLEX-N-GATE MEXICO     1   RP00203
# 866                                 KERN LIEBERS MEXICO     1   EE00063
# 1046                             EDGAR GARCIA HERNANDEZ     1  TUE00378
# ...

# %%
#Filtro O (OR)
filtro9=df_pp[(df_pp["PRECIO_UNITARIO"] > 10000) | (df["NOMBRE_VENDEDOR"] == "ALFREDO CANELA")]
filtro9
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 18    F37061 2022-01-05            ALFREDO CANELA
# 19    F37061 2022-01-05            ALFREDO CANELA
# 20    F37061 2022-01-05            ALFREDO CANELA
# 29    F37078 2022-01-07            ALFREDO CANELA
# ...      ...        ...                       ...
# 1405  F39812 2022-12-22            ALFREDO CANELA
# 1407  F39815 2022-12-22            ALFREDO CANELA
# 1408  F39815 2022-12-22            ALFREDO CANELA
# 1409  F39816 2022-12-22            ALFREDO CANELA
# 1412  F39824 2022-12-23            ALFREDO CANELA
#
#                            NOMBRE_CLIENTE  CANT    CVE_ART  \
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1    RP00165
# 18                               ELICAMEX     5   WRE-2133
# 19                               ELICAMEX     7   WRE-2774
# 20                               ELICAMEX     3   WRE-4885
# 29                  CLAVOS NACIONALES C.N    30  BOBINA001
# ...

# %%
#Filtro NOT
filtro10=df[~(df["PRECIO_UNITARIO"] <= 15000) & ~(df["CANT"] >= 4)]
filtro10
# Out:
#      CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 373   F37734 2022-03-28   DIEGO ARMANDO LEON DURAN
# 419   F37817 2022-03-31             ALFREDO CANELA
# 479   F37933 2022-04-20  LETICIA RAMIREZ HERNANDEZ
# 672   F38352 2022-06-10             ALFREDO CANELA
# 842   F38648 2022-07-22  LETICIA RAMIREZ HERNANDEZ
# 866   F38705 2022-07-29             ALFREDO CANELA
# 931   F38850 2022-08-18  LETICIA RAMIREZ HERNANDEZ
# 960   F38910 2022-08-25             ALFREDO CANELA
# 1046  F39088 2022-09-20  LETICIA RAMIREZ HERNANDEZ
# 1101  F39191 2022-09-30  LETICIA RAMIREZ HERNANDEZ
# 1253  F39503 2022-11-04             ALFREDO CANELA
# 1288  F39576 2022-11-15             ALFREDO CANELA
# 1360  F39716 2022-12-07             ALFREDO CANELA
#
#                                          NOMBRE_CLIENTE  CANT    CVE_ART  \
# 373                                   DIECASTING CELAYA     2    BO00005
# 419          FABRICACION Y MONTAJE DE EQUIPO INDUSTRIAL     1   GAB00014
# ...

# %%
#Convertir archivo filtrado a CSV
filtro4.to_csv("Filtro4_Act1.csv")
filtro5.to_csv("Filtro5_Act1.csv")
filtro6.to_csv("Filtro6_Act1.csv")
filtro7.to_csv("Filtro7_Act1.csv")
filtro8.to_csv("Filtro8_Act1.csv")
filtro9.to_csv("Filtro9_Act1.csv")
filtro10.to_csv("Filtro10_Act1.csv")
